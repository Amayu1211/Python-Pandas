# %%
#Create a simple Pandas DataFrame:

import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#refer to the row index:
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#use a list of indexes:
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %% [markdown]
# # Read  Csv File

# %%
import pandas as pd

df = pd.read_csv('data1.csv')

print(df.to_string())
# Out:
#           SYMBOL  SERIES         DATE1   PREV_CLOSE   OPEN_PRICE   HIGH_PRICE   LOW_PRICE  LAST_PRICE   CLOSE_PRICE   AVG_PRICE   TTL_TRD_QNTY   TURNOVER_LACS   NO_OF_TRADES  DELIV_QTY  DELIV_PER
# 0      20MICRONS      EQ   10-Aug-2021        63.90        65.45        65.45       59.00        60.2         60.30       61.99         202877          125.76           3524     132936      65.53
# 1     21STCENMGM      EQ   10-Aug-2021        25.25        25.75        25.75       25.75       25.75         25.75       25.75           1503            0.39             17       1503        100
# 2     3IINFOTECH      BE   10-Aug-2021         8.75         8.90         9.00        8.35        8.65          8.50        8.66        4731953          409.76           7656          -          -
# 3        3MINDIA      EQ   10-Aug-2021     24319.60     24500.00     24500.00    23700.00    23937.15      23922.70    23965.43          12585         3016.05           1438      11417      90.72
# ...

# %% [markdown]
# # Get Current Working Dictionary

# %%
import pandas as pd

df = pd.read_csv('data1.csv')
df
# Out:
#           SYMBOL  SERIES         DATE1   PREV_CLOSE   OPEN_PRICE   HIGH_PRICE  \
# 0      20MICRONS      EQ   10-Aug-2021        63.90        65.45        65.45
# 1     21STCENMGM      EQ   10-Aug-2021        25.25        25.75        25.75
# 2     3IINFOTECH      BE   10-Aug-2021         8.75         8.90         9.00
# 3        3MINDIA      EQ   10-Aug-2021     24319.60     24500.00     24500.00
# 4         3PLAND      BE   10-Aug-2021        15.20        15.00        15.85
# ...          ...     ...           ...          ...          ...          ...
# 2052      ZOMATO      EQ   10-Aug-2021       130.60       131.00       131.45
# 2053        ZOTA      EQ   10-Aug-2021       353.40       335.75       347.60
# 2054       ZUARI      BE   10-Aug-2021       139.60       138.10       140.00
# 2055   ZUARIGLOB      BE   10-Aug-2021       145.50       145.50       145.50
# 2056   ZYDUSWELL      EQ   10-Aug-2021      2259.00      2267.00      2275.00
#
# ...

# %%
import pandas as pd

df = pd.read_csv('data1.csv')
df.head()
# Out:
#        SYMBOL  SERIES         DATE1   PREV_CLOSE   OPEN_PRICE   HIGH_PRICE  \
# 0   20MICRONS      EQ   10-Aug-2021        63.90        65.45        65.45
# 1  21STCENMGM      EQ   10-Aug-2021        25.25        25.75        25.75
# 2  3IINFOTECH      BE   10-Aug-2021         8.75         8.90         9.00
# 3     3MINDIA      EQ   10-Aug-2021     24319.60     24500.00     24500.00
# 4      3PLAND      BE   10-Aug-2021        15.20        15.00        15.85
#
#     LOW_PRICE  LAST_PRICE   CLOSE_PRICE   AVG_PRICE   TTL_TRD_QNTY  \
# 0       59.00        60.2         60.30       61.99         202877
# 1       25.75       25.75         25.75       25.75           1503
# 2        8.35        8.65          8.50        8.66        4731953
# 3    23700.00    23937.15      23922.70    23965.43          12585
# 4       14.75          15         15.00       15.08           7202
#
#     TURNOVER_LACS   NO_OF_TRADES  DELIV_QTY  DELIV_PER
# 0          125.76           3524     132936      65.53
# ...

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Sara\Pandas

# %% [markdown]
# # Checked Columns

# %%
import pandas as pd

i = pd.read_csv('C:\\Users\\Sara\\pandas\\data1.csv')

i

print(i.columns)
# Out:
# Index(['SYMBOL', ' SERIES', ' DATE1', ' PREV_CLOSE', ' OPEN_PRICE',
#        ' HIGH_PRICE', ' LOW_PRICE', ' LAST_PRICE', ' CLOSE_PRICE',
#        ' AVG_PRICE', ' TTL_TRD_QNTY', ' TURNOVER_LACS', ' NO_OF_TRADES',
#        ' DELIV_QTY', ' DELIV_PER'],
#       dtype='object')

# %% [markdown]
# # READ FILE FROM DESKTOP

# %%
import pandas as pd


i = pd.read_csv('C:\\Users\\Sara\\Desktop\\csv file\\student data.csv')

i
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %% [markdown]
# # No Of Rows

# %%
import pandas as pd
i = pd.read_csv('C:\\Users\\Sara\\pandas\\data1.csv',nrows=6)
i
# Out:
#        SYMBOL  SERIES         DATE1   PREV_CLOSE   OPEN_PRICE   HIGH_PRICE  \
# 0   20MICRONS      EQ   10-Aug-2021        63.90        65.45        65.45
# 1  21STCENMGM      EQ   10-Aug-2021        25.25        25.75        25.75
# 2  3IINFOTECH      BE   10-Aug-2021         8.75         8.90         9.00
# 3     3MINDIA      EQ   10-Aug-2021     24319.60     24500.00     24500.00
# 4      3PLAND      BE   10-Aug-2021        15.20        15.00        15.85
# 5      5PAISA      EQ   10-Aug-2021       507.35       502.00       521.65
#
#     LOW_PRICE   LAST_PRICE   CLOSE_PRICE   AVG_PRICE   TTL_TRD_QNTY  \
# 0       59.00        60.20         60.30       61.99         202877
# 1       25.75        25.75         25.75       25.75           1503
# 2        8.35         8.65          8.50        8.66        4731953
# 3    23700.00     23937.15      23922.70    23965.43          12585
# 4       14.75        15.00         15.00       15.08           7202
# ...

# %% [markdown]
# # USECOLS

# %%
import pandas as pd
i = pd.read_csv('C:\\Users\\Sara\\pandas\\data1.csv',usecols = [0])
i
# Out:
#           SYMBOL
# 0      20MICRONS
# 1     21STCENMGM
# 2     3IINFOTECH
# 3        3MINDIA
# 4         3PLAND
# ...          ...
# 2052      ZOMATO
# 2053        ZOTA
# 2054       ZUARI
# 2055   ZUARIGLOB
# 2056   ZYDUSWELL
#
# [2057 rows x 1 columns]

# %%
import pandas as pd
i = pd.read_csv('C:\\Users\\Sara\\pandas\\data1.csv',usecols = [0,3])
i
# Out:
#           SYMBOL   PREV_CLOSE
# 0      20MICRONS        63.90
# 1     21STCENMGM        25.25
# 2     3IINFOTECH         8.75
# 3        3MINDIA     24319.60
# 4         3PLAND        15.20
# ...          ...          ...
# 2052      ZOMATO       130.60
# 2053        ZOTA       353.40
# 2054       ZUARI       139.60
# 2055   ZUARIGLOB       145.50
# 2056   ZYDUSWELL      2259.00
#
# [2057 rows x 2 columns]

# %% [markdown]
# # Skip Rows

# %%
import pandas as pd
i = pd.read_csv('C:\\Users\\Sara\\pandas\\data1.csv',skiprows=[3])
i
# Out:
#           SYMBOL  SERIES         DATE1   PREV_CLOSE   OPEN_PRICE   HIGH_PRICE  \
# 0      20MICRONS      EQ   10-Aug-2021        63.90        65.45        65.45
# 1     21STCENMGM      EQ   10-Aug-2021        25.25        25.75        25.75
# 2        3MINDIA      EQ   10-Aug-2021     24319.60     24500.00     24500.00
# 3         3PLAND      BE   10-Aug-2021        15.20        15.00        15.85
# 4         5PAISA      EQ   10-Aug-2021       507.35       502.00       521.65
# ...          ...     ...           ...          ...          ...          ...
# 2051      ZOMATO      EQ   10-Aug-2021       130.60       131.00       131.45
# 2052        ZOTA      EQ   10-Aug-2021       353.40       335.75       347.60
# 2053       ZUARI      BE   10-Aug-2021       139.60       138.10       140.00
# 2054   ZUARIGLOB      BE   10-Aug-2021       145.50       145.50       145.50
# 2055   ZYDUSWELL      EQ   10-Aug-2021      2259.00      2267.00      2275.00
#
# ...

# %%
import pandas as pd
i = pd.read_csv('C:\\Users\\Sara\\pandas\\data1.csv',skiprows=[1,3,5])
i
# Out:
#           SYMBOL  SERIES         DATE1   PREV_CLOSE   OPEN_PRICE   HIGH_PRICE  \
# 0     21STCENMGM      EQ   10-Aug-2021        25.25        25.75        25.75
# 1        3MINDIA      EQ   10-Aug-2021     24319.60     24500.00     24500.00
# 2         5PAISA      EQ   10-Aug-2021       507.35       502.00       521.65
# 3        63MOONS      EQ   10-Aug-2021       100.70       102.00       103.90
# 4      667GS2050      GS   10-Aug-2021        97.70        97.00        97.00
# ...          ...     ...           ...          ...          ...          ...
# 2049      ZOMATO      EQ   10-Aug-2021       130.60       131.00       131.45
# 2050        ZOTA      EQ   10-Aug-2021       353.40       335.75       347.60
# 2051       ZUARI      BE   10-Aug-2021       139.60       138.10       140.00
# 2052   ZUARIGLOB      BE   10-Aug-2021       145.50       145.50       145.50
# 2053   ZYDUSWELL      EQ   10-Aug-2021      2259.00      2267.00      2275.00
#
# ...

# %% [markdown]
# # index_column

# %%
import pandas as pd
i = pd.read_csv('C:\\Users\\Sara\\Desktop\\csv file\\student data.csv',index_col=0)
i
# Out:
#             Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Student ID
# 1001           10          2             9                       3
# 1002           10          6             8                       2
# 1003           10          3             8                       2
# 1004           11          0            10                       1
# 1005           11          4             7                       2
# 1006           11         10             7                       0
# 1007           12          4             6                       0
# 1008           12         10             6                       2
# 1009           12          2             8                       2
# 1010           12          6             9                       1
#
#             Mobile Games hrs  Percantege
# Student ID
# 1001                       5          50
# 1002                       0          80
# 1003                       4          60
# ...

# %% [markdown]
# # header=None

# %%
import pandas as pd
i = pd.read_csv('C:\\Users\\Sara\\Desktop\\csv file\\student data.csv',header=None)
i
# Out:
#              0      1          2             3                       4  \
# 0   Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1         1001     10          2             9                       3
# 2         1002     10          6             8                       2
# 3         1003     10          3             8                       2
# 4         1004     11          0            10                       1
# 5         1005     11          4             7                       2
# 6         1006     11         10             7                       0
# 7         1007     12          4             6                       0
# 8         1008     12         10             6                       2
# 9         1009     12          2             8                       2
# 10        1010     12          6             9                       1
#
#                    5           6
# 0   Mobile Games hrs  Percantege
# 1                  5          50
# ...
